# %%
# %matplotlib inline
from matplotlib import pyplot as plt 
plt.plot([4,6,8],[2,4,5])
plt.show()

# %%
# %matplotlib inline
from matplotlib import pyplot as plt 
from matplotlib import style

style.use('ggplot')
x= [4,6,8]
y= [2,4,5]
x1 = [3,2,3]
y1 = [3,6,7]
plt.plot(x, y, label="first")
plt.plot(x1, y1, label=)
plt.title('mahesh data')
plt.xlabel('current')
plt.ylabel('Voltage')

plt.show()
